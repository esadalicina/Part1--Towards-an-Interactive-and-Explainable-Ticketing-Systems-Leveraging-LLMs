# %%
import pandas as pd
file_path = "/home/users/elicina/Master-Thesis/Dataset/Cleaned_Dataset.csv"
df = pd.read_csv(file_path)
df
# Out:
#                                                  product  \
# 0                                        Debt collection
# 1                            Credit card or prepaid card
# 2      Credit reporting, credit repair services, or o...
# 3      Credit reporting, credit repair services, or o...
# 4                            Checking or savings account
# ...                                                  ...
# 20925                        Credit card or prepaid card
# 20926                        Credit card or prepaid card
# 20927                        Checking or savings account
# 20928                        Credit card or prepaid card
# 20929                                        Payday loan
#
#                                  complaint_what_happened  \
# 0      Good morning my name is XXXX XXXX and I apprec...
# 1      I upgraded my XXXX XXXX card in XX/XX/2018 and...
# 2      Chase Card was reported on XX/XX/2019. However...
# ...
